# %%
# Importing Liabraries
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import cv2
# %matplotlib inline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
import joblib
import json

# %%
# Reading a Test image
img = cv2.imread("test_images/Jennifer.jpg")
img.shape
# Out:
# (177, 284, 3)

# %%
# Plotting a Test image
plt.imshow(img)

# %%
# Plotting the Test image as GrayScale image instead of a RBG image
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
plt.imshow(gray, cmap = "gray")

# %%
face_cascade = cv2.CascadeClassifier("opencv/haarcascades/haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier("opencv/haarcascades/haarcascade_eye.xml")
face_glass_cascade = cv2.CascadeClassifier("opencv/haarcascades/haarcascade_eye_tree_eyeglasses.xml")

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[88, 34, 99, 99]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (88, 34, 99, 99)

# %%
face_img = cv2.rectangle(img, (x,y), (x+w,y+h), (255,0,0), 2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        
plt.figure()
plt.imshow(face_img, cmap = "gray")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap = "gray")

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread("test_images/Jennifer.jpg")
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes("test_images/Jennifer.jpg")
plt.imshow(cropped_image)

# %%
path_to_data = "dataset/"
path_to_crop_data = "dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['dataset/cropped',
#  'dataset/Emma Stone',
#  'dataset/Jennifer Lawrence',
#  'dataset/Leonardo Dicaprio',
#  'dataset/Robert De Niro',
#  'dataset/Tom Hanks']

# %%
import shutil
if os.path.exists(path_to_crop_data):
    shutil.rmtree(path_to_crop_data)
os.mkdir(path_to_crop_data)

# %%
cropped_image_dirs = []
ceo_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    ceo_name = img_dir.split('/')[-1]    
    ceo_file_names_dict[ceo_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_crop_data + ceo_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            
            cropped_file_name = ceo_name + str(count) + ".jpg"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            
            cv2.imwrite(cropped_file_path, roi_color)
            ceo_file_names_dict[ceo_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  dataset/cropped/Emma Stone
# Generating cropped images in folder:  dataset/cropped/Jennifer Lawrence
# Generating cropped images in folder:  dataset/cropped/Leonardo Dicaprio
# Generating cropped images in folder:  dataset/cropped/Robert De Niro
# Generating cropped images in folder:  dataset/cropped/Tom Hanks

# %%
ceo_file_names_dict = {}
for img_dir in cropped_image_dirs:
    ceo_name = img_dir.split('dataset/cropped/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    ceo_file_names_dict[ceo_name] = file_list
ceo_file_names_dict
# Out:
# {'Emma Stone': ['dataset/cropped/Emma Stone\\Emma Stone1.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone10.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone11.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone12.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone13.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone14.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone15.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone16.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone17.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone18.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone19.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone2.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone20.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone21.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone22.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone23.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone24.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone25.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone26.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone27.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone28.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone29.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone3.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone30.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone31.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone32.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone33.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone34.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone35.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone36.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone37.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone38.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone39.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone4.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone40.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone41.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone42.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone43.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone44.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone45.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone46.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone47.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone48.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone49.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone5.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone50.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone51.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone52.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone53.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone54.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone55.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone56.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone57.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone58.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone59.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone6.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone60.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone61.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone62.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone63.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone64.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone65.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone66.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone67.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone68.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone69.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone7.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone70.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone71.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone72.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone73.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone74.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone75.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone76.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone77.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone78.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone79.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone8.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone80.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone9.jpg'],
#  'Jennifer Lawrence': ['dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence1.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence10.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence100.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence101.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence102.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence103.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence104.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence105.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence106.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence107.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence108.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence109.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence11.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence110.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence111.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence112.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence113.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence114.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence115.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence116.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence117.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence118.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence119.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence12.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence120.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence121.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence122.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence123.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence124.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence125.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence126.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence127.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence128.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence129.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence13.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence130.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence131.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence132.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence133.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence134.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence135.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence136.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence137.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence138.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence139.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence14.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence140.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence141.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence142.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence143.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence144.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence145.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence146.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence147.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence148.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence149.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence15.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence150.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence151.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence152.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence153.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence154.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence155.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence156.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence157.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence158.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence159.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence16.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence160.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence161.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence162.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence163.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence164.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence165.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence166.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence167.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence168.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence169.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence17.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence170.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence171.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence172.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence173.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence174.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence175.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence176.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence177.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence178.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence179.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence18.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence180.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence181.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence182.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence183.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence184.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence185.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence186.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence187.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence188.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence189.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence19.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence190.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence191.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence192.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence193.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence194.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence195.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence196.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence197.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence198.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence199.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence2.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence20.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence200.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence201.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence202.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence203.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence204.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence205.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence206.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence207.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence208.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence209.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence21.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence210.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence211.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence212.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence213.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence214.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence215.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence216.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence217.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence218.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence219.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence22.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence220.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence221.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence222.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence223.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence224.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence225.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence226.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence227.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence228.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence229.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence23.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence230.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence231.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence232.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence233.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence234.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence235.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence236.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence237.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence238.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence239.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence24.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence25.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence26.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence27.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence28.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence29.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence3.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence30.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence31.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence32.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence33.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence34.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence35.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence36.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence37.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence38.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence39.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence4.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence40.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence41.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence42.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence43.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence44.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence45.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence46.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence47.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence48.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence49.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence5.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence50.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence51.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence52.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence53.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence54.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence55.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence56.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence57.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence58.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence59.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence6.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence60.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence61.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence62.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence63.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence64.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence65.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence66.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence67.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence68.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence69.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence7.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence70.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence71.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence72.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence73.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence74.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence75.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence76.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence77.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence78.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence79.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence8.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence80.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence81.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence82.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence83.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence84.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence85.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence86.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence87.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence88.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence89.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence9.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence90.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence91.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence92.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence93.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence94.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence95.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence96.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence97.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence98.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence99.jpg'],
#  'Leonardo Dicaprio': ['dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio1.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio10.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio100.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio101.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio102.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio103.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio104.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio105.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio106.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio107.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio108.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio109.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio11.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio110.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio111.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio112.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio113.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio114.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio115.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio116.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio12.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio13.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio14.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio15.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio16.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio17.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio18.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio19.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio2.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio20.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio21.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio22.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio23.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio24.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio25.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio26.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio27.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio28.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio29.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio3.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio30.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio31.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio32.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio33.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio34.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio35.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio36.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio37.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio38.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio39.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio4.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio40.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio41.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio42.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio43.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio44.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio45.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio46.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio47.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio48.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio49.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio5.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio50.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio51.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio52.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio53.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio54.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio55.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio56.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio57.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio58.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio59.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio6.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio60.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio61.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio62.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio63.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio64.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio65.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio66.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio67.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio68.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio69.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio7.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio70.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio71.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio72.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio73.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio74.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio75.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio76.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio77.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio78.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio79.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio8.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio80.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio81.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio82.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio83.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio84.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio85.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio86.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio87.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio88.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio89.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio9.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio90.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio91.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio92.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio93.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio94.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio95.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio96.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio97.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio98.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio99.jpg'],
#  'Robert De Niro': ['dataset/cropped/Robert De Niro\\Robert De Niro1.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro10.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro11.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro12.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro13.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro14.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro15.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro16.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro17.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro18.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro19.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro2.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro20.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro21.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro22.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro23.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro24.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro25.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro26.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro27.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro28.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro29.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro3.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro30.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro31.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro32.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro33.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro34.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro35.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro36.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro37.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro38.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro39.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro4.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro40.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro41.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro42.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro43.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro44.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro45.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro46.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro47.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro48.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro49.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro5.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro50.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro51.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro52.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro53.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro54.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro55.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro56.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro57.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro58.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro59.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro6.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro60.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro61.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro62.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro63.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro64.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro65.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro66.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro67.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro68.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro69.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro7.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro70.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro71.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro72.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro73.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro74.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro75.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro76.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro77.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro78.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro79.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro8.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro80.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro9.jpg'],
#  'Tom Hanks': ['dataset/cropped/Tom Hanks\\Tom Hanks1.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks10.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks11.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks12.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks13.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks14.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks15.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks16.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks17.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks18.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks19.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks2.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks20.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks21.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks22.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks23.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks24.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks25.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks26.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks27.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks28.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks29.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks3.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks30.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks31.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks32.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks33.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks34.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks35.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks36.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks37.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks38.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks39.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks4.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks40.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks41.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks42.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks43.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks44.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks45.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks46.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks47.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks48.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks49.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks5.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks50.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks51.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks52.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks53.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks54.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks55.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks56.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks57.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks58.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks59.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks6.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks60.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks61.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks62.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks63.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks64.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks65.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks66.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks67.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks68.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks69.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks7.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks70.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks71.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks72.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks73.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks8.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks9.jpg']}

# %%
# Wevelet Transformation

# %%
import pywt

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
ceo_file_names_dict
# Out:
# {'Emma Stone': ['dataset/cropped/Emma Stone\\Emma Stone1.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone10.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone11.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone12.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone13.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone14.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone15.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone16.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone17.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone18.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone19.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone2.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone20.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone21.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone22.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone23.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone24.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone25.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone26.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone27.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone28.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone29.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone3.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone30.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone31.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone32.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone33.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone34.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone35.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone36.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone37.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone38.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone39.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone4.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone40.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone41.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone42.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone43.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone44.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone45.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone46.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone47.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone48.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone49.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone5.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone50.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone51.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone52.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone53.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone54.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone55.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone56.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone57.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone58.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone59.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone6.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone60.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone61.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone62.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone63.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone64.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone65.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone66.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone67.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone68.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone69.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone7.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone70.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone71.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone72.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone73.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone74.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone75.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone76.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone77.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone78.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone79.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone8.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone80.jpg',
#   'dataset/cropped/Emma Stone\\Emma Stone9.jpg'],
#  'Jennifer Lawrence': ['dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence1.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence10.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence100.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence101.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence102.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence103.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence104.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence105.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence106.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence107.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence108.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence109.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence11.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence110.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence111.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence112.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence113.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence114.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence115.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence116.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence117.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence118.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence119.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence12.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence120.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence121.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence122.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence123.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence124.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence125.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence126.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence127.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence128.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence129.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence13.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence130.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence131.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence132.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence133.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence134.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence135.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence136.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence137.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence138.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence139.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence14.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence140.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence141.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence142.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence143.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence144.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence145.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence146.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence147.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence148.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence149.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence15.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence150.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence151.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence152.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence153.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence154.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence155.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence156.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence157.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence158.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence159.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence16.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence160.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence161.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence162.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence163.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence164.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence165.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence166.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence167.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence168.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence169.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence17.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence170.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence171.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence172.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence173.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence174.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence175.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence176.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence177.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence178.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence179.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence18.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence180.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence181.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence182.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence183.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence184.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence185.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence186.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence187.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence188.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence189.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence19.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence190.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence191.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence192.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence193.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence194.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence195.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence196.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence197.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence198.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence199.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence2.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence20.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence200.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence201.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence202.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence203.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence204.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence205.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence206.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence207.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence208.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence209.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence21.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence210.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence211.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence212.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence213.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence214.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence215.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence216.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence217.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence218.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence219.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence22.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence220.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence221.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence222.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence223.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence224.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence225.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence226.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence227.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence228.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence229.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence23.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence230.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence231.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence232.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence233.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence234.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence235.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence236.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence237.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence238.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence239.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence24.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence25.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence26.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence27.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence28.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence29.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence3.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence30.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence31.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence32.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence33.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence34.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence35.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence36.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence37.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence38.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence39.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence4.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence40.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence41.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence42.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence43.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence44.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence45.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence46.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence47.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence48.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence49.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence5.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence50.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence51.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence52.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence53.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence54.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence55.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence56.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence57.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence58.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence59.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence6.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence60.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence61.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence62.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence63.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence64.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence65.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence66.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence67.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence68.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence69.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence7.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence70.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence71.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence72.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence73.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence74.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence75.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence76.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence77.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence78.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence79.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence8.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence80.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence81.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence82.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence83.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence84.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence85.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence86.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence87.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence88.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence89.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence9.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence90.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence91.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence92.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence93.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence94.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence95.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence96.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence97.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence98.jpg',
#   'dataset/cropped/Jennifer Lawrence\\Jennifer Lawrence99.jpg'],
#  'Leonardo Dicaprio': ['dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio1.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio10.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio100.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio101.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio102.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio103.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio104.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio105.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio106.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio107.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio108.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio109.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio11.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio110.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio111.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio112.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio113.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio114.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio115.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio116.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio12.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio13.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio14.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio15.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio16.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio17.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio18.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio19.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio2.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio20.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio21.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio22.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio23.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio24.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio25.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio26.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio27.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio28.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio29.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio3.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio30.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio31.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio32.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio33.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio34.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio35.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio36.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio37.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio38.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio39.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio4.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio40.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio41.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio42.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio43.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio44.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio45.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio46.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio47.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio48.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio49.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio5.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio50.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio51.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio52.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio53.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio54.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio55.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio56.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio57.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio58.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio59.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio6.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio60.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio61.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio62.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio63.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio64.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio65.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio66.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio67.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio68.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio69.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio7.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio70.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio71.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio72.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio73.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio74.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio75.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio76.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio77.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio78.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio79.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio8.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio80.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio81.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio82.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio83.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio84.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio85.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio86.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio87.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio88.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio89.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio9.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio90.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio91.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio92.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio93.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio94.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio95.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio96.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio97.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio98.jpg',
#   'dataset/cropped/Leonardo Dicaprio\\Leonardo Dicaprio99.jpg'],
#  'Robert De Niro': ['dataset/cropped/Robert De Niro\\Robert De Niro1.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro10.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro11.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro12.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro13.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro14.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro15.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro16.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro17.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro18.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro19.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro2.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro20.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro21.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro22.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro23.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro24.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro25.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro26.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro27.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro28.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro29.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro3.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro30.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro31.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro32.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro33.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro34.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro35.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro36.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro37.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro38.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro39.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro4.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro40.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro41.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro42.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro43.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro44.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro45.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro46.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro47.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro48.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro49.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro5.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro50.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro51.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro52.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro53.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro54.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro55.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro56.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro57.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro58.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro59.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro6.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro60.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro61.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro62.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro63.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro64.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro65.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro66.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro67.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro68.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro69.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro7.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro70.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro71.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro72.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro73.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro74.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro75.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro76.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro77.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro78.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro79.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro8.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro80.jpg',
#   'dataset/cropped/Robert De Niro\\Robert De Niro9.jpg'],
#  'Tom Hanks': ['dataset/cropped/Tom Hanks\\Tom Hanks1.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks10.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks11.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks12.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks13.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks14.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks15.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks16.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks17.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks18.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks19.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks2.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks20.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks21.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks22.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks23.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks24.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks25.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks26.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks27.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks28.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks29.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks3.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks30.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks31.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks32.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks33.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks34.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks35.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks36.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks37.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks38.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks39.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks4.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks40.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks41.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks42.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks43.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks44.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks45.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks46.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks47.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks48.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks49.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks5.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks50.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks51.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks52.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks53.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks54.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks55.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks56.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks57.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks58.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks59.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks6.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks60.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks61.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks62.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks63.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks64.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks65.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks66.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks67.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks68.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks69.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks7.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks70.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks71.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks72.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks73.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks8.jpg',
#   'dataset/cropped/Tom Hanks\\Tom Hanks9.jpg']}

# %%
class_dict = {}
count = 0
for ceo_name in ceo_file_names_dict.keys():
    class_dict[ceo_name] = count
    count = count + 1
class_dict
# Out:
# {'Emma Stone': 0,
#  'Jennifer Lawrence': 1,
#  'Leonardo Dicaprio': 2,
#  'Robert De Niro': 3,
#  'Tom Hanks': 4}

# %%
X, y = [], []
for ceo_name, training_files in ceo_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[ceo_name])

# %%
len(X)
# Out:
# 588

# %%
len(y)
# Out:
# 588

# %%
len(X[0])
# Out:
# 4096

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (588, 4096)

# %%
X[0]
# Out:
# array([ 31.,  55., 115., ..., 163., 186., 254.])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state = 0)
pipe = Pipeline([("scaler", StandardScaler()),("svc", SVC(kernel = "rbf", C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7142857142857143

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.86      0.57      0.69        21
#           1       0.66      0.98      0.79        55
#           2       0.77      0.65      0.70        31
#           3       0.92      0.46      0.61        24
#           4       0.62      0.50      0.55        16
#
# avg / total       0.75      0.71      0.70       147

# %%
model_params = {
    'svm': {
        'model': svm.SVC(probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='ovr'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.707483
# 1        random_forest    0.507937
# 2  logistic_regression    0.718821
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(memory=None,
#       steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('svc', SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#    decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#    max_iter=-1, probability=True, random_state=None, shrinking=True,
#    tol=0.001, verbose=False))]), 'random_forest': Pipeline(memory=None,
#       steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('randomforestclassifier', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min...n_jobs=1,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False))]), 'logistic_regression': Pipeline(memory=None,
#       steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('logisticregression', LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#            intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#            penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#            verbose=0, warm_start=False))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.6938775510204082

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5102040816326531

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7006802721088435

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 9,  7,  1,  0,  4],
#        [ 0, 52,  2,  0,  1],
#        [ 2,  7, 18,  3,  1],
#        [ 0,  5,  2, 14,  3],
#        [ 0,  3,  2,  2,  9]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Emma Stone': 0,
#  'Jennifer Lawrence': 1,
#  'Leonardo Dicaprio': 2,
#  'Robert De Niro': 3,
#  'Tom Hanks': 4}

# %%
# Save the model as a pickle in a file
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %%
# Saving Class Dictionary
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
